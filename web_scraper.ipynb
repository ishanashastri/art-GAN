# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# download wikipage
page = "https://www.posterlad.cz/posters/shapes-only/"
result = requests.get(page)

result
# Out:
# <Response [200]>

# %%
# if successful parse the download into a BeautifulSoup object, which allows easy manipulation 
if result.status_code == 200:
    soup = BeautifulSoup(result.content, "html.parser")
    
imgs = soup.find_all("div", class_='ws-item-offer')

# %%
image_info = []

for i in imgs:
    image_tag = i.findChildren("img")
    if image_tag[0]["alt"]!='popular':
        image_info.append((image_tag[0]["src"], image_tag[0]["alt"]))

image_info
# Out:
# [('/media/produkty/r49ns_1591960120.jpg', 'Armonia'),
#  ('/media/produkty/80opw_1591715852.jpg', 'Yoyo'),
#  ('/media/produkty/akkcw_1591626361.jpg', 'm018'),
#  ('/media/produkty/6n04v_1591372444.jpg', 'Venango'),
#  ('/media/produkty/etis9_1591274925.jpg', 'Fuji'),
#  ('/media/produkty/hxwmq_1591184876.jpg', 'Oceano'),
#  ('/media/produkty/juh85_1590751489.jpg', 'Play'),
#  ('/media/produkty/fsirx_1590678425.jpg', 'Crumpled Up'),
#  ('/media/produkty/9es17_1590578087.jpg', 'Mozajka'),
#  ('/media/produkty/ima9i_1590326316.jpg', 'm017'),
#  ('/media/produkty/jq0fo_1590267027.jpg', 'Tranquilo'),
#  ('/media/produkty/98w2k_1590150602.jpg', 'Polaroid'),
#  ('/media/produkty/92xy7_1590060367.jpg', 'Murano'),
#  ('/media/produkty/rpdu9_1589977125.jpg', 'Haarlem'),
#  ('/media/produkty/jct3q_1589891054.jpg', 'Burano'),
#  ('/media/produkty/rbcm3_1589718351.jpg', 'm016'),
#  ('/media/produkty/iedar_1589457820.jpg', 'Way Home'),
#  ('/media/produkty/flokk_1589202697.jpg', 'Gold Veins'),
# ...

# %%
def download_image(image):
    response = requests.get(image[0], stream=True)
    realname = ''.join(e for e in image[1] if e.isalnum())
    print(realname)
    
    file = open("C://Users//nemo3//Desktop//art-GAN//data//shapes//{}.jpg".format(realname), 'wb')
    
    response.raw.decode_content = True
    shutil.copyfileobj(response.raw, file)
    del response

# %%
for i in range(0, len(image_info)):
    download_image(image_info[i])
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-18-6d4f89b49de1> in <module>
#       1 for i in range(0, len(image_info)):
# ----> 2     download_image(image_info[i])
#
# <ipython-input-17-686c151efda5> in download_image(image)
#       1 def download_image(image):
# ----> 2     response = requests.get(image[0], stream=True)
#       3     realname = ''.join(e for e in image[1] if e.isalnum())
#       4     print(realname)
#       5
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ...
